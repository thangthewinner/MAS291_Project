# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./original_data/Sleep_health_and_lifestyle_dataset.csv')

# %%
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %% [markdown]
# #### Get Sleep Duration vs Stress Level for the project

# %%
final_df = df[['Person ID', 'Gender', 'Sleep Duration', 'Stress Level']]

# %%
final_df = final_df.rename(columns={
    'Person ID': 'ID',
    'Sleep Duration': 'SleepDuration',
    'Stress Level': 'StressLevel'
})

# %%
final_df.set_index('ID', inplace=True)

# %%
final_df[final_df['StressLevel']>=7]
# Out:
#      Gender  SleepDuration  StressLevel
# ID
# 2      Male            6.2            8
# 3      Male            6.2            8
# 4      Male            5.9            8
# 5      Male            5.9            8
# 6      Male            5.9            8
# ..      ...            ...          ...
# 308  Female            6.5            7
# 309  Female            6.6            7
# 310  Female            6.6            7
# 311  Female            6.6            7
# 312  Female            6.6            7
#
# [120 rows x 3 columns]

# %%
final_df.to_csv('./project_data/Sleep_Stress.csv')
